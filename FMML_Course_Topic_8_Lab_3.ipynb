# %% [markdown]
# <a href="https://colab.research.google.com/github/PadalaGangaLakshmi/FMML_MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 07:16:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   173MB/s    in 0.4s
#
# 2024-03-26 07:16:07 (173 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22430  1606.08476v1  This paper proposes a novel dynamic Hierarchic...  stat
# 8919   1704.07626v4  We propose a novel, semi-supervised approach t...    cs
# 34893   1308.2930v6  This sequential technical report extends some ...    cs
# 38357  1701.03051v1  As microblogging services like Twitter are bec...    cs
# 29478  1709.05188v5  Occluded face detection is a challenging detec...    cs
# ...             ...                                                ...   ...
# 40262  1802.10367v1  Detecting objects and their 6D poses from only...    cs
# 38921   1401.5966v2  In this paper, we propose a method for image b...    cs
# 38589   1110.1358v2  We study theoretical runtime guarantees for a ...    cs
# 4400   1704.06363v1  Training convolutional networks (CNN's) that f...    cs
# 7025   1709.01894v1  We present a practical way of introducing conv...  stat
#
#                                                    title  year  \
# 22430  Dynamic Hierarchical Dirichlet Process for Abn...  2016
# 8919      Taxonomy Induction using Hypernym Subsequences  2017
# 34893  Semistability-Based Convergence Analysis for P...  2013
# 38357  Efficient Twitter Sentiment Classification usi...  2017
# 29478  Masquer Hunter: Adversarial Occlusion-aware Fa...  2017
# ...                                                  ...   ...
# 40262  Deep-6DPose: Recovering 6D Object Pose from a ...  2018
# 38921  Image Block Loss Restoration Using Sparsity Pa...  2014
# 38589         Runtime Guarantees for Regression Problems  2011
# 4400   Hard Mixtures of Experts for Large Scale Weakl...  2017
# 7025                    Convolutional Gaussian Processes  2017
#
#                                                 keywords
# 22430  [hierarchical, dirichlet, considers, dependenc...
# 8919   [supervised, induction, vocabulary, approaches...
# 34893  [sequential, technical, semistability, converg...
# 38357  [microblogging, influential, globalised, senti...
# 29478  [detection, challenging, detection, appearance...
# ...                                                  ...
# 40262  [detecting, important, applications, significa...
# 38921  [restoration, representation, information, eff...
# 38589  [theoretical, guarantees, optimization, infere...
# 4400   [convolutional, minibatch, stochastic, effecti...
# 7025   [practical, introducing, convolutional, struct...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22430    [hierarchical, dirichlet, considers, dependenc...
# 8919     [supervised, induction, vocabulary, approaches...
# 34893    [sequential, technical, semistability, converg...
# 38357    [microblogging, influential, globalised, senti...
# 29478    [detection, challenging, detection, appearance...
#                                ...
# 6795     [automating, statistical, modelling, challengi...
# 22981    [optimizing, constraints, invocations, decompo...
# 38484    [uninterrupted, streetscapes, buildings, diame...
# 22844    [prediction, lifestyle, important, diagnosing,...
# 28294    [progression, aesthetically, rendering, indivi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8653 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="47bb1426-6925-4cca-ad99-2c81d785d61a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47bb1426-6925-4cca-ad99-2c81d785d61a")) {                    Plotly.newPlot(                        "47bb1426-6925-4cca-ad99-2c81d785d61a",                        [{"x":["dirichlet","algorithms","observations","processing","intractable","hierarchical","abnormality","dependence","incrementally","synthetic","successive","consideration","computationally","observation","performance","inference","classification","conventional","sequences","behaviour","posterior","detection","sequential","considers","outperforms","languages","experiments","empirically","typically","subsequences","probabilistic","supervised","demonstrate","extracted","importantly","vocabulary","robustness","carefully","framework","approaches","induction","knowledge","convergence","multiagent","technical","optimization","coordination","experimental","extensively","techniques","supervision","perspective","sentiments","sentiment","technique","additional","heuristic","performed","microblogging","previously","accuracies","analysing","effectively","constrained","computation","subjective","frequently","efficient","introduce","evaluations","influential","subjectivity","segmentation","introduces","recognize","benchmark","extensive","specifically","landmarks","detecting","auxiliary","consequently","accordingly","confidences","segmenting","adversarial","occlusion","predicted","significantly","variations","difficult","competitive","appearance","challenging","simultaneously","occlusions","supervisory","textimage","categorized","questions","relatively","pragmatic","according","retrieval","connection","comparing","unlabeled","answering","ingredient","favorably","computing","continuously","alternatives","representing","evaluation","introduced","similarity","connected","attributed","automatically","important","identifying","automated","distinguishing","significant","overlapping","candidate","contained","information","developed","considerably","algorithm","understand","unanswered","implemented","historical","communities","effective","addressing","candidates","community","reasonably","identified","structural","informative","structured","intervention","estimating","exploration","underlying","functions","discovery","optimally","identifies","unstructured","meanwhile","improving","scattered","situation","frameworks","bottleneck","semantically","accommodate","heterogeneous","annotations","recurrent","different","progressive","annotated","advantage","annotation","concentrated","interests","weighting","analyzing","navigation","requirements","parameters","clustering","application","efficiently","sensitive","collected","repositories","initialize","graphical","generalized","interactive","directionality","conditional","furthermore","semantics","representation","interpretation","preference","incompletely","questioning","elicitation","reflecting","statements"],"y":[20,593,72,286,18,101,2,28,17,125,22,31,88,59,881,204,523,104,120,28,55,335,80,40,255,109,623,75,107,3,153,208,575,126,32,35,101,26,548,439,18,349,122,5,31,322,11,395,36,353,42,60,8,52,246,105,58,132,3,91,27,8,102,69,141,39,33,381,312,40,8,6,200,69,50,222,180,164,13,70,25,37,29,3,20,94,22,42,294,75,149,129,75,283,114,20,2,2,7,68,70,2,106,128,44,62,52,58,4,24,124,18,29,76,251,141,139,66,14,188,360,80,105,7,249,29,54,21,685,207,28,815,76,0,101,23,15,254,25,30,76,10,49,70,41,108,17,59,68,116,216,55,15,25,23,15,118,2,46,26,24,33,10,27,53,153,698,7,64,77,53,6,20,24,70,27,42,241,142,263,151,62,78,7,7,55,68,29,3,106,161,107,365,63,29,2,3,6,9,13],"type":"bar"},{"x":["dirichlet","algorithms","observations","processing","intractable","hierarchical","abnorm ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.574468085106383);'>Generation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>Multimedia</span> <span style='background-color:rgba(0, 255, 0, 0.8125);'>Artifacts</span> <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Extractive</span> <span style='background-color:rgba(0, 255, 0, 0.631578947368421);'>Summarization</span> <span style=''>based</span> <span style=''>Approach</span> <br/><br/><span style=''>We</span> <span style=''>explore</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>content</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>address</span> <span style=''>the</span> <span style=''>issue</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>coherence</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.574468085106383);'>generation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>multimedia</span> <span style='background-color:rgba(0, 255, 0, 0.8125);'>artifacts</span> <span style=''>We</span> <span style=''>use</span> <span style=''>audio</span> <span style=''>and</span> <span style=''>video</span> <span style=''>to</span> <span style=''>present</span> <span style=''>two</span> <span style=''>case</span> <span style=''>studies</span> <span style='background-color:rgba(0, 255, 0, 0.574468085106383);'>generation</span> <span style=''>of</span> <span style=''>film</span> <span style=''>tributes</span> <span style=''>and</span> <span style=''>lecture</span> <span style=''>driven</span> <span style=''>science</span> <span style=''>talks</span> <span style=''>For</span> <span style=''>content</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>we</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>centrality</span> <span style=''>based</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diversity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.631578947368421);'>summarization</span> <span style=''>along</span> <span style=''>with</span> <span style=''>topic</span> <span style=''>analysis</span> <span style=''>To</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>coherence</span> <span style=''>we</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>emotional</span> <span style=''>content</span> <span style=''>of</span> <span style=''>music</span> <span style=''>for</span> <span style=''>film</span> <span style=''>tributes</span> <span style=''>and</span> <span style=''>ensure</span> <span style=''>topic</span> <span style='background-color:rgba(0, 255, 0, 0.3560975609756098);'>similarity</span> <span style=''>between</span> <span style=''>lectures</span> <span style=''>and</span> <span style=''>documentaries</span> <span style=''>for</span> <span style=''>science</span> <span style=''>talks</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>Composition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>production</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>multimedia</span> <span style='background-color:rgba(0, 255, 0, 0.8125);'>artifacts</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>addressed</span> <span style=''>as</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Accelerating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Permutation</span> <span style=''>Testing</span> <span style=''>in</span> <span style=''>Voxel</span> <span style=''>wise</span> <span style=''>Analysis</span> <span style=''>through</span> <span style=''>Subspace</span> <span style=''>Tracking</span> <span style=''>A</span> <span style=''>new</span> <span style=''>plugin</span> <span style=''>for</span> <span style=''>SnPM</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Permutation</span> <span style=''>testing</span> <span style=''>is</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obtaining</span> <span style=''>the</span> <span style=''>max</span> <span style=''>null</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>used</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrected</span> <span style=''>p</span> <span style=''>values</span> <span style=''>that</span> <span style=''>provide</span> <span style=''>strong</span> <span style=''>control</span> <span style=''>of</span> <span style=''>false</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>positives</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroimaging</span> <span style=''>however</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>burden</span> <span style=''>of</span> <span style=''>running</span> <span style=''>such</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>by</span> <span style=''>viewing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>testing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>a</span> <span style=''>very</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>testing</span> <span style=''>matrix</span> <span style=''>T</span> <span style=''>one</span> <span style=''>can</span> <span style=''>exploit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style=''>test</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>runtime</span> <span style=''>under</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>see</span> <span style=''>that</span> <span style=''>T</span> <span style=''>is</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>plus</span> <span style=''>a</span> <span style=''>low</span> <span style=''>variance</span> <span style=''>residual</span> <span style=''>This</span> <span style=''>makes</span> <span style=''>T</span> <span style=''>a</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>PAC</span> <span style=''>Bayes</span> <span style=''>Iterated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Logarithm</span> <span style=''>Bounds</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>Martingale</span> <span style=''>Mixtures</span> <br/><br/><span style=''>We</span> <span style=''>give</span> <span style=''>tight</span> <span style='background-color:rgba(255, 0, 0, 0.5172413793103449);'>concentration</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>mixtures</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>martingales</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>uniform</span> <span style=''>over</span> <span style=''>(a)</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3352941176470589);'>distributions</span> <span style=''>in</span> <span style=''>a</span> <span style=''>PAC</span> <span style=''>Bayes</span> <span style=''>sense</span> <span style=''>and</span> <span style=''>(b)</span> <span style=''>all</span> <span style=''>finite</span> <span style=''>times</span> <span style=''>These</span> <span style=''>bounds</span> <span style=''>are</span> <span style=''>proved</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>martingale</span> <span style=''>variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555555);'>Bernstein</span> <span style='background-color:rgba(255, 0, 0, 0.37142857142857144);'>inequalities</span> <span style=''>and</span> <span style=''>sharpening</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>simplifying</span> <span style=''>prior</span> <span style=''>work</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style=''>networks</span> <br/><br/><span style=''>Link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>network</span> <span style=''>analysis</span> <span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>notably</span> <span style=''>in</span> <span style=''>genetics</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style=''>network</span> <span style=''>may</span> <span style=''>not</span> <span style=''>contain</span> <span style=''>any</span> <span style=''>negative</span> <span style=''>examples</span> <span style=''>of</span> <span style=''>absent</span> <span style=''>edges</span> <span style=''>which</span> <span style=''>creates</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulty</span> <span style=''>for</span> <span style=''>many</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>which</span> <span style=''>treats</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>network</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sample</span> <span style=''>of</span> <span style=''>the</span> <span style=''>true</span> <span style=''>network</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>sampling</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>positive</span> <span style=''>and</span> <span style=''>negative</span> <span style=''>examples</span> <span style=''>We</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>relative</span> <span style=''>ranking</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>links</span> <span style=''>by</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariates</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>on</span> <span style=''>network</span> <span style=''>topology</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirically</span> <span style=''>the</span> <span style=''>method</span> <span style=''>performs</span> <span style=''>well</span> <span style=''>under</span> <span style=''>many</span> <span style=''>settings</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>when</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>network</span> <span style=''>is</span> <span style=''>sparse</span> <span style=''>We</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>method</span> <span style=''>to</span> <span style=''>a</span> <span style=''>protein</span> <span style=''>protein</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10117983553807651)
# 	information (0.24490525563103324)
# 	different (0.24955309259921343)
# 	experimental (0.14122273864855203)
# 	representation (0.13049696102967465)
# 	segmentation (0.07150518412584912)
# 	knowledge (0.12477654629960672)
# 	detection (0.11977118341079729)
# 	recognition (0.1276367536646407)
# 	convolutional (0.14837325706113694)
#
# Some Statistics words are:
# 	variational (0.1018472291562656)
# 	stochastic (0.13479780329505742)
# 	variables (0.13779331003494757)
# 	statistical (0.15127309036445333)
# 	theoretical (0.15526709935097355)
# 	algorithm (0.3974038941587619)
# 	distribution (0.19121318022965553)
# 	inference (0.19520718921617575)
# 	dimensional (0.18572141787319021)
# 	regression (0.18072890664003993)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9f585248-9076-493c-bc2d-93ab3c9f495f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f585248-9076-493c-bc2d-93ab3c9f495f")) {                    Plotly.newPlot(                        "9f585248-9076-493c-bc2d-93ab3c9f495f",                        [{"x":["dirichlet","algorithms","observations","processing","intractable","hierarchical","abnormality","dependence","incrementally","synthetic","successive","consideration","computationally","observation","performance","inference","classification","conventional","sequences","behaviour","posterior","detection","sequential","considers","outperforms","languages","experiments","empirically","typically","subsequences","probabilistic","supervised","demonstrate","extracted","importantly","vocabulary","robustness","carefully","framework","approaches","induction","knowledge","convergence","multiagent","technical","optimization","coordination","experimental","extensively","techniques","supervision","perspective","sentiments","sentiment","technique","additional","heuristic","performed","microblogging","previously","accuracies","analysing","effectively","constrained","computation","subjective","frequently","efficient","introduce","evaluations","influential","subjectivity","segmentation","introduces","recognize","benchmark","extensive","specifically","landmarks","detecting","auxiliary","consequently","accordingly","confidences","segmenting","adversarial","occlusion","predicted","significantly","variations","difficult","competitive","appearance","challenging","simultaneously","occlusions","supervisory","textimage","categorized","questions","relatively","pragmatic","according","retrieval","connection","comparing","unlabeled","answering","ingredient","favorably","computing","continuously","alternatives","representing","evaluation","introduced","similarity","connected","attributed","automatically","important","identifying","automated","distinguishing","significant","overlapping","candidate","contained","information","developed","considerably","algorithm","understand","unanswered","implemented","historical","communities","effective","addressing","candidates","community","reasonably","identified","structural","informative","structured","intervention","estimating","exploration","underlying","functions","discovery","optimally","identifies","unstructured","meanwhile","improving","scattered","situation","frameworks","bottleneck","semantically","accommodate","heterogeneous","annotations","recurrent","different","progressive","annotated","advantage","annotation","concentrated","interests","weighting","analyzing","navigation","requirements","parameters","clustering","application","efficiently","sensitive","collected","repositories","initialize","graphical","generalized","interactive","directionality","conditional","furthermore","semantics","representation","interpretation","preference","incompletely","questioning","elicitation","reflecting","statements","constraints","threshold","procedure","dominance","decomposes","utilities","specified","combining","computational","directions","operation","themselves","generalizing","properties","operations","architectures","implement","strategies","convolutional","experimentally","invariance","popularity","motivation","possibility","contributions","assumption","qualitative","regardless","influence","increasing","addiction","recommendation","effectiveness","viewpoint","selection","applications","deterministic","dimensional","limitation","correlations","formulation","extremely","evaluated","variational","processes","stochastic","successful","expressive","approximation","identification","demonstrated","comparison","scalability","modification","structure","geometric", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unanswered
# 	therapies
# 	looseness
# 	tibshirani
# 	cumulants
# 	overconfident
# 	vectorial
# 	procrustes
# 	blockmodel
# 	cytometric
# 	cytometry
# 	trilinear
# 	metropolis
# 	missforest
# 	visualise
# 	underdetermined
# 	invariances
# 	contingent
# 	smoothers
# 	recombines
# Some words which never appear in Statistics papers:
# 	multiagent
# 	microblogging
# 	occlusions
# 	textimage
# 	pragmatic
# 	directionality
# 	dominance
# 	addiction
# 	inseparable
# 	mysterious
# 	neighbours
# 	installed
# 	container
# 	starcraft
# 	competent
# 	pretrained
# 	happiness
# 	logistics
# 	equilibria
# 	pansharpening

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.07370750599373e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
